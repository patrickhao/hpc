# %% [markdown]
# 如何在不依赖模版的情况下找到最佳的schedule，与基于模板的autotvm不同，auto-scheduler不需要任何模板，用户只需要编写计算声明，如需任何schedule命令或模板，auto-scheduler可以自动生成一个大的搜索空间，并在空间中找到最优的schedule

# %%
import os

import numpy as np
import tvm
from tvm import te, auto_scheduler

# %% [markdown]
# 定义矩阵乘法

# %%
@auto_scheduler.register_workload
def matmul_add(N, L, M, dtype):
    A = te.placeholder((N, L), name="A", dtype=dtype)
    B = te.placeholder((L, M), name="B", dtype=dtype)
    C = te.placeholder((N, M), name="C", dtype=dtype)

    k = te.reduce_axis((0, L), name="k")
    matmul = te.compute(
        (N, M),
        lambda i, j: te.sum(A[i, k] * B[k, j], axis=k),
        name="matmul",
        # 开启对tensor B的自动排布转换
        attrs={"layout_free_placeholers": [B]}, 
    )
    out = te.compute((N, M), lambda i, j: matmul[i, j] + C[i, j], name="out")

    return [A, B, C, out]

# %% [markdown]
# 创建搜索任务
#
# 在这里为这个矩阵乘法质地你个特定的参数，如下面是两个大小为1024*1024的矩阵乘法

# %%
target = tvm.target.Target("llvm")
N = L = M = 1024
task = tvm.auto_scheduler.SearchTask(func=matmul_add, args=(N, L, M, "float32"), target=target)

# 检查计算图
print("Computational DAG:")
print(task.compute_dag)
# Out:
# Computational DAG:
# A = PLACEHOLDER [1024, 1024]
# B = PLACEHOLDER [1024, 1024]
# matmul(i, j) += (A[i, k]*B[k, j])
# C = PLACEHOLDER [1024, 1024]
# out(i, j) = (matmul[i, j] + C[i, j])

# %% [markdown]
# 下面来为auto-scheduler设置参数
#
# + `num_measure_trials`表示搜索过程中可用的测试试验次数
# + 用`RecordToFile`将测试记录记录到文件`matmul.json`中

# %%
log_file = "matmul.json"
tune_option = auto_scheduler.TuningOptions(
    num_measure_trials=10,
    measure_callbacks=[auto_scheduler.RecordToFile(log_file)],
    verbose=2,
)

# %% [markdown]
# 开始搜索

# %%
# 运行auto-tuning
task.tune(tune_option)
# 应用最佳schedule
sch, args = task.apply_best(log_file)
# Out:
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2019	fail_ct: 0	Time elapsed: 1.28
# GA Iter: 0	Max score: 0.9985	Min score: 0.9350	#Pop: 128	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9999	Min score: 0.9850	#Pop: 128	#M+: 1380	#M-: 71
# EvolutionarySearch		#s: 128	Time elapsed: 5.68
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 10 programs to measure:
# ..........**********
# ==================================================
# No: 1	GFLOPS: 30.84 / 30.84	results: MeasureResult(cost:[0.0697], error_no:0, all_cost:0.46, Tstamp:1677585142.24)
# ==================================================
# Placeholder: A, B, C
# matmul auto_unroll: 16
# parallel i.0@j.0@i.1@j.1@ (0,8)
#   for k.0 (0,512)
#     for i.2 (0,2)
#       for j.2 (0,64)
#         for k.1 (0,2)
#           for i.3 (0,64)
#             vectorize j.3 (0,16)
#               matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 2	GFLOPS: 61.41 / 61.41	results: MeasureResult(cost:[0.0350], error_no:0, all_cost:0.98, Tstamp:1677585142.47)
# ==================================================
# Placeholder: A, B, C
# matmul auto_unroll: 64
# parallel i.0@j.0@i.1@j.1@ (0,16)
#   for k.0 (0,1024)
#     for j.2 (0,16)
#       for i.3 (0,64)
#         vectorize j.3 (0,64)
#           matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 3	GFLOPS: 86.25 / 86.25	results: MeasureResult(cost:[0.0249], error_no:0, all_cost:1.93, Tstamp:1677585142.91)
# ==================================================
# Placeholder: A, B, C
# matmul auto_unroll: 512
# parallel i.0@j.0@i.1@j.1@ (0,4096)
#   for k.0 (0,64)
#     for j.2 (0,8)
#       for k.1 (0,16)
#         for i.3 (0,4)
#           vectorize j.3 (0,8)
#             matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 4	GFLOPS: 17.79 / 86.25	results: MeasureResult(cost:[0.1208], error_no:0, all_cost:0.78, Tstamp:1677585143.47)
# ==================================================
# Placeholder: A, B, C
# matmul auto_unroll: 64
# parallel i.0@j.0@i.1@j.1@ (0,4096)
#   for k.0 (0,128)
#     for i.2 (0,32)
#       for k.1 (0,8)
#         for i.3 (0,8)
#           matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 5	GFLOPS: 51.19 / 86.25	results: MeasureResult(cost:[0.0420], error_no:0, all_cost:0.34, Tstamp:1677585143.73)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@j.1@ (0,512)
#   matmul auto_unroll: 16
#   for k.0 (0,1024)
#     for i.2 (0,128)
#       for j.2 (0,8)
#         vectorize j.3 (0,2)
#           matmul = ...
#   for i.2 (0,128)
#     vectorize j.2 (0,16)
#       out = ...
#
# ==================================================
# No: 6	GFLOPS: 93.87 / 93.87	results: MeasureResult(cost:[0.0229], error_no:0, all_cost:3.38, Tstamp:1677585144.03)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,32)
#   matmul auto_unroll: 512
#   for i.1 (0,8)
#     for j.1 (0,2)
#       for k.0 (0,64)
#         for i.2 (0,16)
#           for j.2 (0,2)
#             for k.1 (0,16)
#               vectorize j.3 (0,64)
#                 matmul = ...
#   for i.1 (0,128)
#     vectorize j.1 (0,256)
#       out = ...
#
# ==================================================
# No: 7	GFLOPS: 26.26 / 93.87	results: MeasureResult(cost:[0.0818], error_no:0, all_cost:0.52, Tstamp:1677585144.44)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@j.1@ (0,4096)
#   matmul auto_unroll: 16
#   for k.0 (0,16)
#     for j.2 (0,64)
#       for k.1 (0,64)
#         for i.3 (0,4)
#           matmul = ...
#   for i.2 (0,4)
#     for j.2 (0,64)
#       out = ...
#
# ==================================================
# No: 8	GFLOPS: 91.65 / 93.87	results: MeasureResult(cost:[0.0234], error_no:0, all_cost:0.40, Tstamp:1677585144.75)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@j.1@ (0,4096)
#   for k.0 (0,1024)
#     for i.3 (0,16)
#       vectorize j.3 (0,16)
#         matmul = ...
#   for i.2 (0,16)
#     vectorize j.2 (0,16)
#       out = ...
#
# ==================================================
# No: 9	GFLOPS: 92.19 / 93.87	results: MeasureResult(cost:[0.0233], error_no:0, all_cost:0.60, Tstamp:1677585145.05)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,16)
#   matmul auto_unroll: 64
#   for i.1 (0,64)
#     for j.1 (0,4)
#       for k.0 (0,512)
#         for i.2 (0,4)
#           for j.2 (0,16)
#             for k.1 (0,2)
#               for i.3 (0,4)
#                 matmul = ...
#   for i.1 (0,1024)
#     for j.1 (0,64)
#       out = ...
#
# ==================================================
# No: 10	GFLOPS: 97.36 / 97.36	results: MeasureResult(cost:[0.0221], error_no:0, all_cost:0.61, Tstamp:1677585145.34)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@ (0,128)
#   for j.1 (0,16)
#     matmul auto_unroll: 512
#     for k.0 (0,128)
#       for i.2 (0,2)
#         for j.2 (0,16)
#           for k.1 (0,8)
#             for i.3 (0,16)
#               matmul = ...
#     for i.2 (0,32)
#       vectorize j.2 (0,16)
#         out = ...
#
# Time elapsed for measurement: 7.26 s
# ----------------------------------------------------------------------
# ------------------------------  [ Done ]
# ----------------------------------------------------------------------

# %% [markdown]
# 检查优化的schedule

# %%
print("Lowered TIR:")
print(tvm.lower(sch, args, simple_mode=True))
# Out:
# Lowered TIR:
# # from tvm.script import ir as I
# # from tvm.script import tir as T
#
# @I.ir_module
# class Module:
#     @T.prim_func
#     def main(A: T.Buffer((1024, 1024), "float32"), B: T.Buffer((1024, 1024), "float32"), C: T.Buffer((1024, 1024), "float32"), out: T.Buffer((1024, 1024), "float32")):
#         T.func_attr({"from_legacy_te_schedule": True, "global_symbol": "main", "tir.noalias": True})
#         for i_outer_outer_j_outer_outer_fused_i_outer_inner_fused in T.parallel(128):
#             matmul = T.allocate([512], "float32", "global")
#             for j_outer_inner in range(16):
#                 matmul_1 = T.Buffer((512,), data=matmul)
#                 matmul_1[0] = T.float32(0)
#                 matmul_1[16] = T.float32(0)
#                 matmul_1[32] = T.float32(0)
#                 matmul_1[48] = T.float32(0)
#                 matmul_1[64] = T.float32(0)
#                 matmul_1[80] = T.float32(0)
#                 matmul_1[96] = T.float32(0)
#                 matmul_1[112] = T.float32(0)
#                 matmul_1[128] = T.float32(0)
#                 matmul_1[144] = T.float32(0)
#                 matmul_1[160] = T.float32(0)
#                 matmul_1[176] = T.float32(0)
#                 matmul_1[192] = T.float32(0)
#                 matmul_1[208] = T.float32(0)
#                 matmul_1[224] = T.float32(0)
#                 matmul_1[240] = T.float32(0)
#                 matmul_1[1] = T.float32(0)
#                 matmul_1[17] = T.float32(0)
#                 matmul_1[33] = T.float32(0)
#                 matmul_1[49] = T.float32(0)
#                 matmul_1[65] = T.float32(0)
#                 matmul_1[81] = T.float32(0)
#                 matmul_1[97] = T.float32(0)
#                 matmul_1[113] = T.float32(0)
#                 matmul_1[129] = T.float32(0)
#                 matmul_1[145] = T.float32(0)
#                 matmul_1[161] = T.float32(0)
#                 matmul_1[177] = T.float32(0)
#                 matmul_1[193] = T.float32(0)
#                 matmul_1[209] = T.float32(0)
#                 matmul_1[225] = T.float32(0)
#                 matmul_1[241] = T.float32(0)
#                 matmul_1[2] = T.float32(0)
#                 matmul_1[18] = T.float32(0)
#                 matmul_1[34] = T.float32(0)
#                 matmul_1[50] = T.float32(0)
#                 matmul_1[66] = T.float32(0)
#                 matmul_1[82] = T.float32(0)
#                 matmul_1[98] = T.float32(0)
#                 matmul_1[114] = T.float32(0)
#                 matmul_1[130] = T.float32(0)
#                 matmul_1[146] = T.float32(0)
#                 matmul_1[162] = T.float32(0)
#                 matmul_1[178] = T.float32(0)
#                 matmul_1[194] = T.float32(0)
#                 matmul_1[210] = T.float32(0)
#                 matmul_1[226] = T.float32(0)
#                 matmul_1[242] = T.float32(0)
#                 matmul_1[3] = T.float32(0)
#                 matmul_1[19] = T.float32(0)
#                 matmul_1[35] = T.float32(0)
#                 matmul_1[51] = T.float32(0)
#                 matmul_1[67] = T.float32(0)
#                 matmul_1[83] = T.float32(0)
#                 matmul_1[99] = T.float32(0)
#                 matmul_1[115] = T.float32(0)
#                 matmul_1[131] = T.float32(0)
#                 matmul_1[147] = T.float32(0)
#                 matmul_1[163] = T.float32(0)
#                 matmul_1[179] = T.float32(0)
#                 matmul_1[195] = T.float32(0)
#                 matmul_1[211] = T.float32(0)
#                 matmul_1[227] = T.float32(0)
#                 matmul_1[243] = T.float32(0)
#                 matmul_1[4] = T.float32(0)
#                 matmul_1[20] = T.float32(0)
#                 matmul_1[36] = T.float32(0)
#                 matmul_1[52] = T.float32(0)
#                 matmul_1[68] = T.float32(0)
#                 matmul_1[84] = T.float32(0)
#                 matmul_1[100] = T.float32(0)
#                 matmul_1[116] = T.float32(0)
#                 matmul_1[132] = T.float32(0)
#                 matmul_1[148] = T.float32(0)
#                 matmul_1[164] = T.float32(0)
#                 matmul_1[180] = T.float32(0)
#                 matmul_1[196] = T.float32(0)
#                 matmul_1[212] = T.float32(0)
#                 matmul_1[228] = T.float32(0)
#                 matmul_1[244] = T.float32(0)
#                 matmul_1[5] = T.float32(0)
#                 matmul_1[21] = T.float32(0)
#                 matmul_1[37] = T.float32(0)
#                 matmul_1[53] = T.float32(0)
#                 matmul_1[69] = T.float32(0)
#                 matmul_1[85] = T.float32(0)
#                 matmul_1[101] = T.float32(0)
#                 matmul_1[117] = T.float32(0)
#                 matmul_1[133] = T.float32(0)
#                 matmul_1[149] = T.float32(0)
#                 matmul_1[165] = T.float32(0)
#                 matmul_1[181] = T.float32(0)
#                 matmul_1[197] = T.float32(0)
#                 matmul_1[213] = T.float32(0)
#                 matmul_1[229] = T.float32(0)
#                 matmul_1[245] = T.float32(0)
#                 matmul_1[6] = T.float32(0)
#                 matmul_1[22] = T.float32(0)
#                 matmul_1[38] = T.float32(0)
#                 matmul_1[54] = T.float32(0)
#                 matmul_1[70] = T.float32(0)
#                 matmul_1[86] = T.float32(0)
#                 matmul_1[102] = T.float32(0)
#                 matmul_1[118] = T.float32(0)
#                 matmul_1[134] = T.float32(0)
#                 matmul_1[150] = T.float32(0)
#                 matmul_1[166] = T.float32(0)
#                 matmul_1[182] = T.float32(0)
#                 matmul_1[198] = T.float32(0)
#                 matmul_1[214] = T.float32(0)
#                 matmul_1[230] = T.float32(0)
#                 matmul_1[246] = T.float32(0)
#                 matmul_1[7] = T.float32(0)
#                 matmul_1[23] = T.float32(0)
#                 matmul_1[39] = T.float32(0)
#                 matmul_1[55] = T.float32(0)
#                 matmul_1[71] = T.float32(0)
#                 matmul_1[87] = T.float32(0)
#                 matmul_1[103] = T.float32(0)
#                 matmul_1[119] = T.float32(0)
#                 matmul_1[135] = T.float32(0)
#                 matmul_1[151] = T.float32(0)
#                 matmul_1[167] = T.float32(0)
#                 matmul_1[183] = T.float32(0)
#                 matmul_1[199] = T.float32(0)
#                 matmul_1[215] = T.float32(0)
#                 matmul_1[231] = T.float32(0)
#                 matmul_1[247] = T.float32(0)
#                 matmul_1[8] = T.float32(0)
#                 matmul_1[24] = T.float32(0)
#                 matmul_1[40] = T.float32(0)
#                 matmul_1[56] = T.float32(0)
#                 matmul_1[72] = T.float32(0)
#                 matmul_1[88] = T.float32(0)
#                 matmul_1[104] = T.float32(0)
#                 matmul_1[120] = T.float32(0)
#                 matmul_1[136] = T.float32(0)
#                 matmul_1[152] = T.float32(0)
#                 matmul_1[168] = T.float32(0)
#                 matmul_1[184] = T.float32(0)
#                 matmul_1[200] = T.float32(0)
#                 matmul_1[216] = T.float32(0)
#                 matmul_1[232] = T.float32(0)
#                 matmul_1[248] = T.float32(0)
#                 matmul_1[9] = T.float32(0)
#                 matmul_1[25] = T.float32(0)
#                 matmul_1[41] = T.float32(0)
#                 matmul_1[57] = T.float32(0)
#                 matmul_1[73] = T.float32(0)
#                 matmul_1[89] = T.float32(0)
#                 matmul_1[105] = T.float32(0)
#                 matmul_1[121] = T.float32(0)
#                 matmul_1[137] = T.float32(0)
#                 matmul_1[153] = T.float32(0)
#                 matmul_1[169] = T.float32(0)
#                 matmul_1[185] = T.float32(0)
#                 matmul_1[201] = T.float32(0)
#                 matmul_1[217] = T.float32(0)
#                 matmul_1[233] = T.float32(0)
#                 matmul_1[249] = T.float32(0)
#                 matmul_1[10] = T.float32(0)
#                 matmul_1[26] = T.float32(0)
#                 matmul_1[42] = T.float32(0)
#                 matmul_1[58] = T.float32(0)
#                 matmul_1[74] = T.float32(0)
#                 matmul_1[90] = T.float32(0)
#                 matmul_1[106] = T.float32(0)
#                 matmul_1[122] = T.float32(0)
#                 matmul_1[138] = T.float32(0)
#                 matmul_1[154] = T.float32(0)
#                 matmul_1[170] = T.float32(0)
#                 matmul_1[186] = T.float32(0)
#                 matmul_1[202] = T.float32(0)
#                 matmul_1[218] = T.float32(0)
#                 matmul_1[234] = T.float32(0)
#                 matmul_1[250] = T.float32(0)
#                 matmul_1[11] = T.float32(0)
#                 matmul_1[27] = T.float32(0)
#                 matmul_1[43] = T.float32(0)
#                 matmul_1[59] = T.float32(0)
#                 matmul_1[75] = T.float32(0)
#                 matmul_1[91] = T.float32(0)
#                 matmul_1[107] = T.float32(0)
#                 matmul_1[123] = T.float32(0)
#                 matmul_1[139] = T.float32(0)
#                 matmul_1[155] = T.float32(0)
#                 matmul_1[171] = T.float32(0)
#                 matmul_1[187] = T.float32(0)
#                 matmul_1[203] = T.float32(0)
#                 matmul_1[219] = T.float32(0)
#                 matmul_1[235] = T.float32(0)
#                 matmul_1[251] = T.float32(0)
#                 matmul_1[12] = T.float32(0)
#                 matmul_1[28] = T.float32(0)
#                 matmul_1[44] = T.float32(0)
#                 matmul_1[60] = T.float32(0)
#                 matmul_1[76] = T.float32(0)
#                 matmul_1[92] = T.float32(0)
#                 matmul_1[108] = T.float32(0)
#                 matmul_1[124] = T.float32(0)
#                 matmul_1[140] = T.float32(0)
#                 matmul_1[156] = T.float32(0)
#                 matmul_1[172] = T.float32(0)
#                 matmul_1[188] = T.float32(0)
#                 matmul_1[204] = T.float32(0)
#                 matmul_1[220] = T.float32(0)
#                 matmul_1[236] = T.float32(0)
#                 matmul_1[252] = T.float32(0)
#                 matmul_1[13] = T.float32(0)
#                 matmul_1[29] = T.float32(0)
#                 matmul_1[45] = T.float32(0)
#                 matmul_1[61] = T.float32(0)
#                 matmul_1[77] = T.float32(0)
#                 matmul_1[93] = T.float32(0)
#                 matmul_1[109] = T.float32(0)
#                 matmul_1[125] = T.float32(0)
#                 matmul_1[141] = T.float32(0)
#                 matmul_1[157] = T.float32(0)
#                 matmul_1[173] = T.float32(0)
#                 matmul_1[189] = T.float32(0)
#                 matmul_1[205] = T.float32(0)
#                 matmul_1[221] = T.float32(0)
#                 matmul_1[237] = T.float32(0)
#                 matmul_1[253] = T.float32(0)
#                 matmul_1[14] = T.float32(0)
#                 matmul_1[30] = T.float32(0)
#                 matmul_1[46] = T.float32(0)
#                 matmul_1[62] = T.float32(0)
#                 matmul_1[78] = T.float32(0)
#                 matmul_1[94] = T.float32(0)
#                 matmul_1[110] = T.float32(0)
#                 matmul_1[126] = T.float32(0)
#                 matmul_1[142] = T.float32(0)
#                 matmul_1[158] = T.float32(0)
#                 matmul_1[174] = T.float32(0)
#                 matmul_1[190] = T.float32(0)
#                 matmul_1[206] = T.float32(0)
#                 matmul_1[222] = T.float32(0)
#                 matmul_1[238] = T.float32(0)
#                 matmul_1[254] = T.float32(0)
#                 matmul_1[15] = T.float32(0)
#                 matmul_1[31] = T.float32(0)
#                 matmul_1[47] = T.float32(0)
#                 matmul_1[63] = T.float32(0)
#                 matmul_1[79] = T.float32(0)
#                 matmul_1[95] = T.float32(0)
#                 matmul_1[111] = T.float32(0)
#                 matmul_1[127] = T.float32(0)
#                 matmul_1[143] = T.float32(0)
#                 matmul_1[159] = T.float32(0)
#                 matmul_1[175] = T.float32(0)
#                 matmul_1[191] = T.float32(0)
#                 matmul_1[207] = T.float32(0)
#                 matmul_1[223] = T.float32(0)
#                 matmul_1[239] = T.float32(0)
#                 matmul_1[255] = T.float32(0)
#                 matmul_1[256] = T.float32(0)
#                 matmul_1[272] = T.float32(0)
#                 matmul_1[288] = T.float32(0)
#                 matmul_1[304] = T.float32(0)
#                 matmul_1[320] = T.float32(0)
#                 matmul_1[336] = T.float32(0)
#                 matmul_1[352] = T.float32(0)
#                 matmul_1[368] = T.float32(0)
#                 matmul_1[384] = T.float32(0)
#                 matmul_1[400] = T.float32(0)
#                 matmul_1[416] = T.float32(0)
#                 matmul_1[432] = T.float32(0)
#                 matmul_1[448] = T.float32(0)
#                 matmul_1[464] = T.float32(0)
#                 matmul_1[480] = T.float32(0)
#                 matmul_1[496] = T.float32(0)
#                 matmul_1[257] = T.float32(0)
#                 matmul_1[273] = T.float32(0)
#                 matmul_1[289] = T.float32(0)
#                 matmul_1[305] = T.float32(0)
#                 matmul_1[321] = T.float32(0)
#                 matmul_1[337] = T.float32(0)
#                 matmul_1[353] = T.float32(0)
#                 matmul_1[369] = T.float32(0)
#                 matmul_1[385] = T.float32(0)
#                 matmul_1[401] = T.float32(0)
#                 matmul_1[417] = T.float32(0)
#                 matmul_1[433] = T.float32(0)
#                 matmul_1[449] = T.float32(0)
#                 matmul_1[465] = T.float32(0)
#                 matmul_1[481] = T.float32(0)
#                 matmul_1[497] = T.float32(0)
#                 matmul_1[258] = T.float32(0)
#                 matmul_1[274] = T.float32(0)
#                 matmul_1[290] = T.float32(0)
#                 matmul_1[306] = T.float32(0)
#                 matmul_1[322] = T.float32(0)
#                 matmul_1[338] = T.float32(0)
#                 matmul_1[354] = T.float32(0)
#                 matmul_1[370] = T.float32(0)
#                 matmul_1[386] = T.float32(0)
#                 matmul_1[402] = T.float32(0)
#                 matmul_1[418] = T.float32(0)
#                 matmul_1[434] = T.float32(0)
#                 matmul_1[450] = T.float32(0)
#                 matmul_1[466] = T.float32(0)
#                 matmul_1[482] = T.float32(0)
#                 matmul_1[498] = T.float32(0)
#                 matmul_1[259] = T.float32(0)
#                 matmul_1[275] = T.float32(0)
#                 matmul_1[291] = T.float32(0)
#                 matmul_1[307] = T.float32(0)
#                 matmul_1[323] = T.float32(0)
#                 matmul_1[339] = T.float32(0)
#                 matmul_1[355] = T.float32(0)
#                 matmul_1[371] = T.float32(0)
#                 matmul_1[387] = T.float32(0)
#                 matmul_1[403] = T.float32(0)
#                 matmul_1[419] = T.float32(0)
#                 matmul_1[435] = T.float32(0)
#                 matmul_1[451] = T.float32(0)
#                 matmul_1[467] = T.float32(0)
#                 matmul_1[483] = T.float32(0)
#                 matmul_1[499] = T.float32(0)
#                 matmul_1[260] = T.float32(0)
#                 matmul_1[276] = T.float32(0)
#                 matmul_1[292] = T.float32(0)
#                 matmul_1[308] = T.float32(0)
#                 matmul_1[324] = T.float32(0)
#                 matmul_1[340] = T.float32(0)
#                 matmul_1[356] = T.float32(0)
#                 matmul_1[372] = T.float32(0)
#                 matmul_1[388] = T.float32(0)
#                 matmul_1[404] = T.float32(0)
#                 matmul_1[420] = T.float32(0)
#                 matmul_1[436] = T.float32(0)
#                 matmul_1[452] = T.float32(0)
#                 matmul_1[468] = T.float32(0)
#                 matmul_1[484] = T.float32(0)
#                 matmul_1[500] = T.float32(0)
#                 matmul_1[261] = T.float32(0)
#                 matmul_1[277] = T.float32(0)
#                 matmul_1[293] = T.float32(0)
#                 matmul_1[309] = T.float32(0)
#                 matmul_1[325] = T.float32(0)
#                 matmul_1[341] = T.float32(0)
#                 matmul_1[357] = T.float32(0)
#                 matmul_1[373] = T.float32(0)
#                 matmul_1[389] = T.float32(0)
#                 matmul_1[405] = T.float32(0)
#                 matmul_1[421] = T.float32(0)
#                 matmul_1[437] = T.float32(0)
#                 matmul_1[453] = T.float32(0)
#                 matmul_1[469] = T.float32(0)
#                 matmul_1[485] = T.float32(0)
#                 matmul_1[501] = T.float32(0)
#                 matmul_1[262] = T.float32(0)
#                 matmul_1[278] = T.float32(0)
#                 matmul_1[294] = T.float32(0)
#                 matmul_1[310] = T.float32(0)
#                 matmul_1[326] = T.float32(0)
#                 matmul_1[342] = T.float32(0)
#                 matmul_1[358] = T.float32(0)
#                 matmul_1[374] = T.float32(0)
#                 matmul_1[390] = T.float32(0)
#                 matmul_1[406] = T.float32(0)
#                 matmul_1[422] = T.float32(0)
#                 matmul_1[438] = T.float32(0)
#                 matmul_1[454] = T.float32(0)
#                 matmul_1[470] = T.float32(0)
#                 matmul_1[486] = T.float32(0)
#                 matmul_1[502] = T.float32(0)
#                 matmul_1[263] = T.float32(0)
#                 matmul_1[279] = T.float32(0)
#                 matmul_1[295] = T.float32(0)
#                 matmul_1[311] = T.float32(0)
#                 matmul_1[327] = T.float32(0)
#                 matmul_1[343] = T.float32(0)
#                 matmul_1[359] = T.float32(0)
#                 matmul_1[375] = T.float32(0)
#                 matmul_1[391] = T.float32(0)
#                 matmul_1[407] = T.float32(0)
#                 matmul_1[423] = T.float32(0)
#                 matmul_1[439] = T.float32(0)
#                 matmul_1[455] = T.float32(0)
#                 matmul_1[471] = T.float32(0)
#                 matmul_1[487] = T.float32(0)
#                 matmul_1[503] = T.float32(0)
#                 matmul_1[264] = T.float32(0)
#                 matmul_1[280] = T.float32(0)
#                 matmul_1[296] = T.float32(0)
#                 matmul_1[312] = T.float32(0)
#                 matmul_1[328] = T.float32(0)
#                 matmul_1[344] = T.float32(0)
#                 matmul_1[360] = T.float32(0)
#                 matmul_1[376] = T.float32(0)
#                 matmul_1[392] = T.float32(0)
#                 matmul_1[408] = T.float32(0)
#                 matmul_1[424] = T.float32(0)
#                 matmul_1[440] = T.float32(0)
#                 matmul_1[456] = T.float32(0)
#                 matmul_1[472] = T.float32(0)
#                 matmul_1[488] = T.float32(0)
#                 matmul_1[504] = T.float32(0)
#                 matmul_1[265] = T.float32(0)
#                 matmul_1[281] = T.float32(0)
#                 matmul_1[297] = T.float32(0)
#                 matmul_1[313] = T.float32(0)
#                 matmul_1[329] = T.float32(0)
#                 matmul_1[345] = T.float32(0)
#                 matmul_1[361] = T.float32(0)
#                 matmul_1[377] = T.float32(0)
#                 matmul_1[393] = T.float32(0)
#                 matmul_1[409] = T.float32(0)
#                 matmul_1[425] = T.float32(0)
#                 matmul_1[441] = T.float32(0)
#                 matmul_1[457] = T.float32(0)
#                 matmul_1[473] = T.float32(0)
#                 matmul_1[489] = T.float32(0)
#                 matmul_1[505] = T.float32(0)
#                 matmul_1[266] = T.float32(0)
#                 matmul_1[282] = T.float32(0)
#                 matmul_1[298] = T.float32(0)
#                 matmul_1[314] = T.float32(0)
#                 matmul_1[330] = T.float32(0)
#                 matmul_1[346] = T.float32(0)
#                 matmul_1[362] = T.float32(0)
#                 matmul_1[378] = T.float32(0)
#                 matmul_1[394] = T.float32(0)
#                 matmul_1[410] = T.float32(0)
#                 matmul_1[426] = T.float32(0)
#                 matmul_1[442] = T.float32(0)
#                 matmul_1[458] = T.float32(0)
#                 matmul_1[474] = T.float32(0)
#                 matmul_1[490] = T.float32(0)
#                 matmul_1[506] = T.float32(0)
#                 matmul_1[267] = T.float32(0)
#                 matmul_1[283] = T.float32(0)
#                 matmul_1[299] = T.float32(0)
#                 matmul_1[315] = T.float32(0)
#                 matmul_1[331] = T.float32(0)
#                 matmul_1[347] = T.float32(0)
#                 matmul_1[363] = T.float32(0)
#                 matmul_1[379] = T.float32(0)
#                 matmul_1[395] = T.float32(0)
#                 matmul_1[411] = T.float32(0)
#                 matmul_1[427] = T.float32(0)
#                 matmul_1[443] = T.float32(0)
#                 matmul_1[459] = T.float32(0)
#                 matmul_1[475] = T.float32(0)
#                 matmul_1[491] = T.float32(0)
#                 matmul_1[507] = T.float32(0)
#                 matmul_1[268] = T.float32(0)
#                 matmul_1[284] = T.float32(0)
#                 matmul_1[300] = T.float32(0)
#                 matmul_1[316] = T.float32(0)
#                 matmul_1[332] = T.float32(0)
#                 matmul_1[348] = T.float32(0)
#                 matmul_1[364] = T.float32(0)
#                 matmul_1[380] = T.float32(0)
#                 matmul_1[396] = T.float32(0)
#                 matmul_1[412] = T.float32(0)
#                 matmul_1[428] = T.float32(0)
#                 matmul_1[444] = T.float32(0)
#                 matmul_1[460] = T.float32(0)
#                 matmul_1[476] = T.float32(0)
#                 matmul_1[492] = T.float32(0)
#                 matmul_1[508] = T.float32(0)
#                 matmul_1[269] = T.float32(0)
#                 matmul_1[285] = T.float32(0)
#                 matmul_1[301] = T.float32(0)
#                 matmul_1[317] = T.float32(0)
#                 matmul_1[333] = T.float32(0)
#                 matmul_1[349] = T.float32(0)
#                 matmul_1[365] = T.float32(0)
#                 matmul_1[381] = T.float32(0)
#                 matmul_1[397] = T.float32(0)
#                 matmul_1[413] = T.float32(0)
#                 matmul_1[429] = T.float32(0)
#                 matmul_1[445] = T.float32(0)
#                 matmul_1[461] = T.float32(0)
#                 matmul_1[477] = T.float32(0)
#                 matmul_1[493] = T.float32(0)
#                 matmul_1[509] = T.float32(0)
#                 matmul_1[270] = T.float32(0)
#                 matmul_1[286] = T.float32(0)
#                 matmul_1[302] = T.float32(0)
#                 matmul_1[318] = T.float32(0)
#                 matmul_1[334] = T.float32(0)
#                 matmul_1[350] = T.float32(0)
#                 matmul_1[366] = T.float32(0)
#                 matmul_1[382] = T.float32(0)
#                 matmul_1[398] = T.float32(0)
#                 matmul_1[414] = T.float32(0)
#                 matmul_1[430] = T.float32(0)
#                 matmul_1[446] = T.float32(0)
#                 matmul_1[462] = T.float32(0)
#                 matmul_1[478] = T.float32(0)
#                 matmul_1[494] = T.float32(0)
#                 matmul_1[510] = T.float32(0)
#                 matmul_1[271] = T.float32(0)
#                 matmul_1[287] = T.float32(0)
#                 matmul_1[303] = T.float32(0)
#                 matmul_1[319] = T.float32(0)
#                 matmul_1[335] = T.float32(0)
#                 matmul_1[351] = T.float32(0)
#                 matmul_1[367] = T.float32(0)
#                 matmul_1[383] = T.float32(0)
#                 matmul_1[399] = T.float32(0)
#                 matmul_1[415] = T.float32(0)
#                 matmul_1[431] = T.float32(0)
#                 matmul_1[447] = T.float32(0)
#                 matmul_1[463] = T.float32(0)
#                 matmul_1[479] = T.float32(0)
#                 matmul_1[495] = T.float32(0)
#                 matmul_1[511] = T.float32(0)
#                 for k_outer, i_outer_inner, j_outer_inner_1 in T.grid(128, 2, 16):
#                     cse_var_25: T.int32 = i_outer_inner * 256 + j_outer_inner_1
#                     cse_var_24: T.int32 = cse_var_25 + 96
#                     cse_var_23: T.int32 = cse_var_25 + 80
#                     cse_var_22: T.int32 = cse_var_25 + 64
#                     cse_var_21: T.int32 = cse_var_25 + 48
#                     cse_var_20: T.int32 = cse_var_25 + 32
#                     cse_var_19: T.int32 = cse_var_25 + 240
#                     cse_var_18: T.int32 = cse_var_25 + 224
#                     cse_var_17: T.int32 = cse_var_25 + 208
#                     cse_var_16: T.int32 = cse_var_25 + 192
#                     cse_var_15: T.int32 = cse_var_25 + 176
#                     cse_var_14: T.int32 = cse_var_25 + 160
#                     cse_var_13: T.int32 = cse_var_25 + 16
#                     cse_var_12: T.int32 = cse_var_25 + 144
#                     cse_var_11: T.int32 = cse_var_25 + 128
#                     cse_var_10: T.int32 = cse_var_25 + 112
#                     cse_var_9: T.int32 = k_outer * 8192 + i_outer_outer_j_outer_outer_fused_i_outer_inner_fused % 64 // 16 * 256 + j_outer_inner * 16 + j_outer_inner_1
#                     cse_var_8: T.int32 = i_outer_outer_j_outer_outer_fused_i_outer_inner_fused // 64 * 524288 + i_outer_outer_j_outer_outer_fused_i_outer_inner_fused % 16 * 32768 + i_outer_inner * 16384 + k_outer * 8
#                     cse_var_7: T.int32 = cse_var_9 + 7168
#                     cse_var_6: T.int32 = cse_var_9 + 6144
#                     cse_var_5: T.int32 = cse_var_9 + 5120
#                     cse_var_4: T.int32 = cse_var_9 + 4096
#                     cse_var_3: T.int32 = cse_var_9 + 3072
#                     cse_var_2: T.int32 = cse_var_9 + 2048
#                     cse_var_1: T.int32 = cse_var_9 + 1024
#                     A_1 = T.Buffer((1048576,), data=A.data)
#                     B_1 = T.Buffer((1048576,), data=B.data)
#                     matmul_1[cse_var_25] = matmul_1[cse_var_25] + A_1[cse_var_8] * B_1[cse_var_9]
#                     matmul_1[cse_var_13] = matmul_1[cse_var_13] + A_1[cse_var_8 + 1024] * B_1[cse_var_9]
#                     matmul_1[cse_var_20] = matmul_1[cse_var_20] + A_1[cse_var_8 + 2048] * B_1[cse_var_9]
#                     matmul_1[cse_var_21] = matmul_1[cse_var_21] + A_1[cse_var_8 + 3072] * B_1[cse_var_9]
#                     matmul_1[cse_var_22] = matmul_1[cse_var_22] + A_1[cse_var_8 + 4096] * B_1[cse_var_9]
#                     matmul_1[cse_var_23] = matmul_1[cse_var_23] + A_1[cse_var_8 + 5120] * B_1[cse_var_9]
#                     matmul_1[cse_var_24] = matmul_1[cse_var_24] + A_1[cse_var_8 + 6144] * B_1[cse_var_9]
#                     matmul_1[cse_var_10] = matmul_1[cse_var_10] + A_1[cse_var_8 + 7168] * B_1[cse_var_9]
#                     matmul_1[cse_var_11] = matmul_1[cse_var_11] + A_1[cse_var_8 + 8192] * B_1[cse_var_9]
#                     matmul_1[cse_var_12] = matmul_1[cse_var_12] + A_1[cse_var_8 + 9216] * B_1[cse_var_9]
#                     matmul_1[cse_var_14] = matmul_1[cse_var_14] + A_1[cse_var_8 + 10240] * B_1[cse_var_9]
#                     matmul_1[cse_var_15] = matmul_1[cse_var_15] + A_1[cse_var_8 + 11264] * B_1[cse_var_9]
#                     matmul_1[cse_var_16] = matmul_1[cse_var_16] + A_1[cse_var_8 + 12288] * B_1[cse_var_9]
#                     matmul_1[cse_var_17] = matmul_1[cse_var_17] + A_1[cse_var_8 + 13312] * B_1[cse_var_9]
#                     matmul_1[cse_var_18] = matmul_1[cse_var_18] + A_1[cse_var_8 + 14336] * B_1[cse_var_9]
#                     matmul_1[cse_var_19] = matmul_1[cse_var_19] + A_1[cse_var_8 + 15360] * B_1[cse_var_9]
#                     matmul_1[cse_var_25] = matmul_1[cse_var_25] + A_1[cse_var_8 + 1] * B_1[cse_var_1]
#                     matmul_1[cse_var_13] = matmul_1[cse_var_13] + A_1[cse_var_8 + 1025] * B_1[cse_var_1]
#                     matmul_1[cse_var_20] = matmul_1[cse_var_20] + A_1[cse_var_8 + 2049] * B_1[cse_var_1]
#                     matmul_1[cse_var_21] = matmul_1[cse_var_21] + A_1[cse_var_8 + 3073] * B_1[cse_var_1]
#                     matmul_1[cse_var_22] = matmul_1[cse_var_22] + A_1[cse_var_8 + 4097] * B_1[cse_var_1]
#                     matmul_1[cse_var_23] = matmul_1[cse_var_23] + A_1[cse_var_8 + 5121] * B_1[cse_var_1]
#                     matmul_1[cse_var_24] = matmul_1[cse_var_24] + A_1[cse_var_8 + 6145] * B_1[cse_var_1]
#                     matmul_1[cse_var_10] = matmul_1[cse_var_10] + A_1[cse_var_8 + 7169] * B_1[cse_var_1]
#                     matmul_1[cse_var_11] = matmul_1[cse_var_11] + A_1[cse_var_8 + 8193] * B_1[cse_var_1]
#                     matmul_1[cse_var_12] = matmul_1[cse_var_12] + A_1[cse_var_8 + 9217] * B_1[cse_var_1]
#                     matmul_1[cse_var_14] = matmul_1[cse_var_14] + A_1[cse_var_8 + 10241] * B_1[cse_var_1]
#                     matmul_1[cse_var_15] = matmul_1[cse_var_15] + A_1[cse_var_8 + 11265] * B_1[cse_var_1]
#                     matmul_1[cse_var_16] = matmul_1[cse_var_16] + A_1[cse_var_8 + 12289] * B_1[cse_var_1]
#                     matmul_1[cse_var_17] = matmul_1[cse_var_17] + A_1[cse_var_8 + 13313] * B_1[cse_var_1]
#                     matmul_1[cse_var_18] = matmul_1[cse_var_18] + A_1[cse_var_8 + 14337] * B_1[cse_var_1]
#                     matmul_1[cse_var_19] = matmul_1[cse_var_19] + A_1[cse_var_8 + 15361] * B_1[cse_var_1]
#                     matmul_1[cse_var_25] = matmul_1[cse_var_25] + A_1[cse_var_8 + 2] * B_1[cse_var_2]
#                     matmul_1[cse_var_13] = matmul_1[cse_var_13] + A_1[cse_var_8 + 1026] * B_1[cse_var_2]
#                     matmul_1[cse_var_20] = matmul_1[cse_var_20] + A_1[cse_var_8 + 2050] * B_1[cse_var_2]
#                     matmul_1[cse_var_21] = matmul_1[cse_var_21] + A_1[cse_var_8 + 3074] * B_1[cse_var_2]
#                     matmul_1[cse_var_22] = matmul_1[cse_var_22] + A_1[cse_var_8 + 4098] * B_1[cse_var_2]
#                     matmul_1[cse_var_23] = matmul_1[cse_var_23] + A_1[cse_var_8 + 5122] * B_1[cse_var_2]
#                     matmul_1[cse_var_24] = matmul_1[cse_var_24] + A_1[cse_var_8 + 6146] * B_1[cse_var_2]
#                     matmul_1[cse_var_10] = matmul_1[cse_var_10] + A_1[cse_var_8 + 7170] * B_1[cse_var_2]
#                     matmul_1[cse_var_11] = matmul_1[cse_var_11] + A_1[cse_var_8 + 8194] * B_1[cse_var_2]
#                     matmul_1[cse_var_12] = matmul_1[cse_var_12] + A_1[cse_var_8 + 9218] * B_1[cse_var_2]
#                     matmul_1[cse_var_14] = matmul_1[cse_var_14] + A_1[cse_var_8 + 10242] * B_1[cse_var_2]
#                     matmul_1[cse_var_15] = matmul_1[cse_var_15] + A_1[cse_var_8 + 11266] * B_1[cse_var_2]
#                     matmul_1[cse_var_16] = matmul_1[cse_var_16] + A_1[cse_var_8 + 12290] * B_1[cse_var_2]
#                     matmul_1[cse_var_17] = matmul_1[cse_var_17] + A_1[cse_var_8 + 13314] * B_1[cse_var_2]
#                     matmul_1[cse_var_18] = matmul_1[cse_var_18] + A_1[cse_var_8 + 14338] * B_1[cse_var_2]
#                     matmul_1[cse_var_19] = matmul_1[cse_var_19] + A_1[cse_var_8 + 15362] * B_1[cse_var_2]
#                     matmul_1[cse_var_25] = matmul_1[cse_var_25] + A_1[cse_var_8 + 3] * B_1[cse_var_3]
#                     matmul_1[cse_var_13] = matmul_1[cse_var_13] + A_1[cse_var_8 + 1027] * B_1[cse_var_3]
#                     matmul_1[cse_var_20] = matmul_1[cse_var_20] + A_1[cse_var_8 + 2051] * B_1[cse_var_3]
#                     matmul_1[cse_var_21] = matmul_1[cse_var_21] + A_1[cse_var_8 + 3075] * B_1[cse_var_3]
#                     matmul_1[cse_var_22] = matmul_1[cse_var_22] + A_1[cse_var_8 + 4099] * B_1[cse_var_3]
#                     matmul_1[cse_var_23] = matmul_1[cse_var_23] + A_1[cse_var_8 + 5123] * B_1[cse_var_3]
#                     matmul_1[cse_var_24] = matmul_1[cse_var_24] + A_1[cse_var_8 + 6147] * B_1[cse_var_3]
#                     matmul_1[cse_var_10] = matmul_1[cse_var_10] + A_1[cse_var_8 + 7171] * B_1[cse_var_3]
#                     matmul_1[cse_var_11] = matmul_1[cse_var_11] + A_1[cse_var_8 + 8195] * B_1[cse_var_3]
#                     matmul_1[cse_var_12] = matmul_1[cse_var_12] + A_1[cse_var_8 + 9219] * B_1[cse_var_3]
#                     matmul_1[cse_var_14] = matmul_1[cse_var_14] + A_1[cse_var_8 + 10243] * B_1[cse_var_3]
#                     matmul_1[cse_var_15] = matmul_1[cse_var_15] + A_1[cse_var_8 + 11267] * B_1[cse_var_3]
#                     matmul_1[cse_var_16] = matmul_1[cse_var_16] + A_1[cse_var_8 + 12291] * B_1[cse_var_3]
#                     matmul_1[cse_var_17] = matmul_1[cse_var_17] + A_1[cse_var_8 + 13315] * B_1[cse_var_3]
#                     matmul_1[cse_var_18] = matmul_1[cse_var_18] + A_1[cse_var_8 + 14339] * B_1[cse_var_3]
#                     matmul_1[cse_var_19] = matmul_1[cse_var_19] + A_1[cse_var_8 + 15363] * B_1[cse_var_3]
#                     matmul_1[cse_var_25] = matmul_1[cse_var_25] + A_1[cse_var_8 + 4] * B_1[cse_var_4]
#                     matmul_1[cse_var_13] = matmul_1[cse_var_13] + A_1[cse_var_8 + 1028] * B_1[cse_var_4]
#                     matmul_1[cse_var_20] = matmul_1[cse_var_20] + A_1[cse_var_8 + 2052] * B_1[cse_var_4]
#                     matmul_1[cse_var_21] = matmul_1[cse_var_21] + A_1[cse_var_8 + 3076] * B_1[cse_var_4]
#                     matmul_1[cse_var_22] = matmul_1[cse_var_22] + A_1[cse_var_8 + 4100] * B_1[cse_var_4]
#                     matmul_1[cse_var_23] = matmul_1[cse_var_23] + A_1[cse_var_8 + 5124] * B_1[cse_var_4]
#                     matmul_1[cse_var_24] = matmul_1[cse_var_24] + A_1[cse_var_8 + 6148] * B_1[cse_var_4]
#                     matmul_1[cse_var_10] = matmul_1[cse_var_10] + A_1[cse_var_8 + 7172] * B_1[cse_var_4]
#                     matmul_1[cse_var_11] = matmul_1[cse_var_11] + A_1[cse_var_8 + 8196] * B_1[cse_var_4]
#                     matmul_1[cse_var_12] = matmul_1[cse_var_12] + A_1[cse_var_8 + 9220] * B_1[cse_var_4]
#                     matmul_1[cse_var_14] = matmul_1[cse_var_14] + A_1[cse_var_8 + 10244] * B_1[cse_var_4]
#                     matmul_1[cse_var_15] = matmul_1[cse_var_15] + A_1[cse_var_8 + 11268] * B_1[cse_var_4]
#                     matmul_1[cse_var_16] = matmul_1[cse_var_16] + A_1[cse_var_8 + 12292] * B_1[cse_var_4]
#                     matmul_1[cse_var_17] = matmul_1[cse_var_17] + A_1[cse_var_8 + 13316] * B_1[cse_var_4]
#                     matmul_1[cse_var_18] = matmul_1[cse_var_18] + A_1[cse_var_8 + 14340] * B_1[cse_var_4]
#                     matmul_1[cse_var_19] = matmul_1[cse_var_19] + A_1[cse_var_8 + 15364] * B_1[cse_var_4]
#                     matmul_1[cse_var_25] = matmul_1[cse_var_25] + A_1[cse_var_8 + 5] * B_1[cse_var_5]
#                     matmul_1[cse_var_13] = matmul_1[cse_var_13] + A_1[cse_var_8 + 1029] * B_1[cse_var_5]
#                     matmul_1[cse_var_20] = matmul_1[cse_var_20] + A_1[cse_var_8 + 2053] * B_1[cse_var_5]
#                     matmul_1[cse_var_21] = matmul_1[cse_var_21] + A_1[cse_var_8 + 3077] * B_1[cse_var_5]
#                     matmul_1[cse_var_22] = matmul_1[cse_var_22] + A_1[cse_var_8 + 4101] * B_1[cse_var_5]
#                     matmul_1[cse_var_23] = matmul_1[cse_var_23] + A_1[cse_var_8 + 5125] * B_1[cse_var_5]
#                     matmul_1[cse_var_24] = matmul_1[cse_var_24] + A_1[cse_var_8 + 6149] * B_1[cse_var_5]
#                     matmul_1[cse_var_10] = matmul_1[cse_var_10] + A_1[cse_var_8 + 7173] * B_1[cse_var_5]
#                     matmul_1[cse_var_11] = matmul_1[cse_var_11] + A_1[cse_var_8 + 8197] * B_1[cse_var_5]
#                     matmul_1[cse_var_12] = matmul_1[cse_var_12] + A_1[cse_var_8 + 9221] * B_1[cse_var_5]
#                     matmul_1[cse_var_14] = matmul_1[cse_var_14] + A_1[cse_var_8 + 10245] * B_1[cse_var_5]
#                     matmul_1[cse_var_15] = matmul_1[cse_var_15] + A_1[cse_var_8 + 11269] * B_1[cse_var_5]
#                     matmul_1[cse_var_16] = matmul_1[cse_var_16] + A_1[cse_var_8 + 12293] * B_1[cse_var_5]
#                     matmul_1[cse_var_17] = matmul_1[cse_var_17] + A_1[cse_var_8 + 13317] * B_1[cse_var_5]
#                     matmul_1[cse_var_18] = matmul_1[cse_var_18] + A_1[cse_var_8 + 14341] * B_1[cse_var_5]
#                     matmul_1[cse_var_19] = matmul_1[cse_var_19] + A_1[cse_var_8 + 15365] * B_1[cse_var_5]
#                     matmul_1[cse_var_25] = matmul_1[cse_var_25] + A_1[cse_var_8 + 6] * B_1[cse_var_6]
#                     matmul_1[cse_var_13] = matmul_1[cse_var_13] + A_1[cse_var_8 + 1030] * B_1[cse_var_6]
#                     matmul_1[cse_var_20] = matmul_1[cse_var_20] + A_1[cse_var_8 + 2054] * B_1[cse_var_6]
#                     matmul_1[cse_var_21] = matmul_1[cse_var_21] + A_1[cse_var_8 + 3078] * B_1[cse_var_6]
#                     matmul_1[cse_var_22] = matmul_1[cse_var_22] + A_1[cse_var_8 + 4102] * B_1[cse_var_6]
#                     matmul_1[cse_var_23] = matmul_1[cse_var_23] + A_1[cse_var_8 + 5126] * B_1[cse_var_6]
#                     matmul_1[cse_var_24] = matmul_1[cse_var_24] + A_1[cse_var_8 + 6150] * B_1[cse_var_6]
#                     matmul_1[cse_var_10] = matmul_1[cse_var_10] + A_1[cse_var_8 + 7174] * B_1[cse_var_6]
#                     matmul_1[cse_var_11] = matmul_1[cse_var_11] + A_1[cse_var_8 + 8198] * B_1[cse_var_6]
#                     matmul_1[cse_var_12] = matmul_1[cse_var_12] + A_1[cse_var_8 + 9222] * B_1[cse_var_6]
#                     matmul_1[cse_var_14] = matmul_1[cse_var_14] + A_1[cse_var_8 + 10246] * B_1[cse_var_6]
#                     matmul_1[cse_var_15] = matmul_1[cse_var_15] + A_1[cse_var_8 + 11270] * B_1[cse_var_6]
#                     matmul_1[cse_var_16] = matmul_1[cse_var_16] + A_1[cse_var_8 + 12294] * B_1[cse_var_6]
#                     matmul_1[cse_var_17] = matmul_1[cse_var_17] + A_1[cse_var_8 + 13318] * B_1[cse_var_6]
#                     matmul_1[cse_var_18] = matmul_1[cse_var_18] + A_1[cse_var_8 + 14342] * B_1[cse_var_6]
#                     matmul_1[cse_var_19] = matmul_1[cse_var_19] + A_1[cse_var_8 + 15366] * B_1[cse_var_6]
#                     matmul_1[cse_var_25] = matmul_1[cse_var_25] + A_1[cse_var_8 + 7] * B_1[cse_var_7]
#                     matmul_1[cse_var_13] = matmul_1[cse_var_13] + A_1[cse_var_8 + 1031] * B_1[cse_var_7]
#                     matmul_1[cse_var_20] = matmul_1[cse_var_20] + A_1[cse_var_8 + 2055] * B_1[cse_var_7]
#                     matmul_1[cse_var_21] = matmul_1[cse_var_21] + A_1[cse_var_8 + 3079] * B_1[cse_var_7]
#                     matmul_1[cse_var_22] = matmul_1[cse_var_22] + A_1[cse_var_8 + 4103] * B_1[cse_var_7]
#                     matmul_1[cse_var_23] = matmul_1[cse_var_23] + A_1[cse_var_8 + 5127] * B_1[cse_var_7]
#                     matmul_1[cse_var_24] = matmul_1[cse_var_24] + A_1[cse_var_8 + 6151] * B_1[cse_var_7]
#                     matmul_1[cse_var_10] = matmul_1[cse_var_10] + A_1[cse_var_8 + 7175] * B_1[cse_var_7]
#                     matmul_1[cse_var_11] = matmul_1[cse_var_11] + A_1[cse_var_8 + 8199] * B_1[cse_var_7]
#                     matmul_1[cse_var_12] = matmul_1[cse_var_12] + A_1[cse_var_8 + 9223] * B_1[cse_var_7]
#                     matmul_1[cse_var_14] = matmul_1[cse_var_14] + A_1[cse_var_8 + 10247] * B_1[cse_var_7]
#                     matmul_1[cse_var_15] = matmul_1[cse_var_15] + A_1[cse_var_8 + 11271] * B_1[cse_var_7]
#                     matmul_1[cse_var_16] = matmul_1[cse_var_16] + A_1[cse_var_8 + 12295] * B_1[cse_var_7]
#                     matmul_1[cse_var_17] = matmul_1[cse_var_17] + A_1[cse_var_8 + 13319] * B_1[cse_var_7]
#                     matmul_1[cse_var_18] = matmul_1[cse_var_18] + A_1[cse_var_8 + 14343] * B_1[cse_var_7]
#                     matmul_1[cse_var_19] = matmul_1[cse_var_19] + A_1[cse_var_8 + 15367] * B_1[cse_var_7]
#                 for i_inner in range(32):
#                     cse_var_26: T.int32 = i_outer_outer_j_outer_outer_fused_i_outer_inner_fused // 64 * 524288 + i_outer_outer_j_outer_outer_fused_i_outer_inner_fused % 16 * 32768 + i_inner * 1024 + i_outer_outer_j_outer_outer_fused_i_outer_inner_fused % 64 // 16 * 256 + j_outer_inner * 16
#                     out_1 = T.Buffer((1048576,), data=out.data)
#                     C_1 = T.Buffer((1048576,), data=C.data)
#                     out_1[cse_var_26:cse_var_26 + 16] = matmul_1[i_inner * 16:i_inner * 16 + 16] + C_1[cse_var_26:cse_var_26 + 16]

# %% [markdown]
# 检查正确性并评估

# %%
func = tvm.build(sch, args, target)
a_np = np.random.uniform(size=(N, L)).astype(np.float32)
b_np = np.random.uniform(size=(L, M)).astype(np.float32)
c_np = np.random.uniform(size=(N, M)).astype(np.float32)
out_np = a_np.dot(b_np) + c_np

dev = tvm.cpu()
a_tvm = tvm.nd.array(a_np, device=dev)
b_tvm = tvm.nd.array(b_np, device=dev)
c_tvm = tvm.nd.array(c_np, device=dev)
out_tvm = tvm.nd.empty(out_np.shape, device=dev)
# 预先分配内存，提升性能，防止重复的内存分配
func(a_tvm, b_tvm, c_tvm, out_tvm)

# 检查结果
np.testing.assert_allclose(out_np, out_tvm.numpy(), rtol=1e-3)

# Evaluate execution time.
evaluator = func.time_evaluator(func.entry_name, dev, min_repeat_ms=500)
print(
    "Execution time of this operator: %.3f ms"
    % (np.median(evaluator(a_tvm, b_tvm, c_tvm, out_tvm).results) * 1000)
)
# Out:
# Execution time of this operator: 25.661 ms

# %% [markdown]
# 使用记录文件

# %%
print("Equivalent python schedule:")
print(task.print_best(log_file))
# Out:
# Equivalent python schedule:
# matmul_i, matmul_j, matmul_k = tuple(matmul.op.axis) + tuple(matmul.op.reduce_axis)
# out_i, out_j = tuple(out.op.axis) + tuple(out.op.reduce_axis)
# matmul_i_o_i, matmul_i_i = s[matmul].split(matmul_i, factor=16)
# matmul_i_o_o_i, matmul_i_o_i = s[matmul].split(matmul_i_o_i, factor=2)
# matmul_i_o_o_o, matmul_i_o_o_i = s[matmul].split(matmul_i_o_o_i, factor=16)
# matmul_j_o_i, matmul_j_i = s[matmul].split(matmul_j, factor=1)
# matmul_j_o_o_i, matmul_j_o_i = s[matmul].split(matmul_j_o_i, factor=16)
# matmul_j_o_o_o, matmul_j_o_o_i = s[matmul].split(matmul_j_o_o_i, factor=16)
# matmul_k_o, matmul_k_i = s[matmul].split(matmul_k, factor=8)
# s[matmul].reorder(matmul_i_o_o_o, matmul_j_o_o_o, matmul_i_o_o_i, matmul_j_o_o_i, matmul_k_o, matmul_i_o_i, matmul_j_o_i, matmul_k_i, matmul_i_i, matmul_j_i)
# out_i_o_i, out_i_i = s[out].split(out_i, factor=32)
# out_i_o_o, out_i_o_i = s[out].split(out_i_o_i, factor=16)
# out_j_o_i, out_j_i = s[out].split(out_j, factor=16)
# out_j_o_o, out_j_o_i = s[out].split(out_j_o_i, factor=16)
# s[out].reorder(out_i_o_o, out_j_o_o, out_i_o_i, out_j_o_i, out_i_i, out_j_i)
# s[matmul].compute_at(s[out], out_j_o_i)
# out_i_o_o_j_o_o_fused_i_o_i_fused = s[out].fuse(out_i_o_o, out_j_o_o, out_i_o_i)
# s[out].parallel(out_i_o_o_j_o_o_fused_i_o_i_fused)
# s[matmul].pragma(matmul_i_o_o_o, "auto_unroll_max_step", 512)
# s[matmul].pragma(matmul_i_o_o_o, "unroll_explicit", True)
# s[matmul].vectorize(matmul_j_i)
# s[out].vectorize(out_j_i)

# %% [markdown]
# 恢复搜索比较复杂，需要自己创建搜索策略和cost model，通过日志文件恢复搜索策略和cost model的状态，下面示例进行了5次实验来恢复它们的状态

# %%
def resume_search(task, log_file):
    print("Resume search:")
    cost_model = auto_scheduler.XGBModel()
    cost_model.update_from_file(log_file)
    search_policy = auto_scheduler.SketchPolicy(
        task, cost_model, init_search_callbacks=[auto_scheduler.PreloadMeasuredStates(log_file)]
    )
    tune_option = auto_scheduler.TuningOptions(
        num_measure_trials=5, measure_callbacks=[auto_scheduler.RecordToFile(log_file)]
    )
    task.tune(tune_option, search_policy=search_policy)

resume_search(task, log_file)
# Out:
# Resume search:
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 10 measurement records from matmul.json for ["matmul_add", 1024, 1024, 1024, "float32"]
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2013	fail_ct: 0	Time elapsed: 1.62
# GA Iter: 0	Max score: 0.9972	Min score: 0.9298	#Pop: 128	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9996	Min score: 0.9883	#Pop: 128	#M+: 1374	#M-: 82
# EvolutionarySearch		#s: 128	Time elapsed: 6.73
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 5 programs to measure:
# .....*****
# Time elapsed for measurement: 12.09 s
# ----------------------------------------------------------------------
# ------------------------------  [ Done ]
# ----------------------------------------------------------------------
